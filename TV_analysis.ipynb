# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tv=pd.read_csv("data_set\TV_Final.xls")

# %%
tv
# Out:
#        Brand     Resolution  Size   Selling Price  Original Price  \
# 0    TOSHIBA   Ultra HD LED     55          37999           54990
# 1       TCL   QLED Ultra HD     55          52999          129990
# 2    realme          HD LED     32          13999           17999
# 3        Mi          HD LED     32          14999           19999
# 4    realme          HD LED     32          12999           21999
# ..       ...            ...    ...            ...             ...
# 907    SONY     Full HD LED     43          44999           57900
# 908    SONY     Full HD LED     40          41499           51900
# 909    SONY    Ultra HD LED     65         149990          184990
# 910    SONY          HD LED     32          32900           32900
# 911    SONY     Full HD LED     43          56900           56900
#
#     Operating System  Rating
# 0              VIDAA     4.3
# 1            Android     4.4
# 2            Android     4.3
# 3            Android     4.4
# ...

# %%
tv.shape
# Out:
# (912, 7)

# %%
tv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 912 entries, 0 to 911
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Brand             912 non-null    object
#  1   Resolution        912 non-null    object
#  2   Size              912 non-null    int64
#  3   Selling Price     912 non-null    int64
#  4   Original Price    912 non-null    int64
#  5   Operating System  901 non-null    object
#  6   Rating            692 non-null    float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 50.0+ KB

# %%
tv.dtypes
# Out:
# Brand                object
# Resolution           object
# Size                  int64
# Selling Price         int64
# Original Price        int64
# Operating System     object
# Rating              float64
# dtype: object

# %%
tv1=tv.copy()

# %%
tv.isna().sum()
# Out:
# Brand                 0
# Resolution            0
# Size                  0
# Selling Price         0
# Original Price        0
# Operating System     11
# Rating              220
# dtype: int64

# %% [markdown]
# - operating system as 11 na values
# - rating as 220 na values

# %%
tv.duplicated().sum()
# Out:
# 30

# %% [markdown]
# - there are 30 duplicates

# %%
tv.drop_duplicates(inplace=True)

# %%
tv['Rating'].fillna(0,inplace=True)

# %%
tv.isna().sum()
# Out:
# Brand               0
# Resolution          0
# Size                0
# Selling Price       0
# Original Price      0
# Operating System    0
# Rating              0
# dtype: int64

# %%
tv.dropna(inplace=True)

# %%
tv
# Out:
#        Brand     Resolution  Size   Selling Price  Original Price  \
# 0    TOSHIBA   Ultra HD LED     55          37999           54990
# 1       TCL   QLED Ultra HD     55          52999          129990
# 2    realme          HD LED     32          13999           17999
# 3        Mi          HD LED     32          14999           19999
# 4    realme          HD LED     32          12999           21999
# ..       ...            ...    ...            ...             ...
# 907    SONY     Full HD LED     43          44999           57900
# 908    SONY     Full HD LED     40          41499           51900
# 909    SONY    Ultra HD LED     65         149990          184990
# 910    SONY          HD LED     32          32900           32900
# 911    SONY     Full HD LED     43          56900           56900
#
#     Operating System  Rating
# 0              VIDAA     4.3
# 1            Android     4.4
# 2            Android     4.3
# 3            Android     4.4
# ...

# %%
tv.isna().sum()
# Out:
# Brand               0
# Resolution          0
# Size                0
# Selling Price       0
# Original Price      0
# Operating System    0
# Rating              0
# dtype: int64

# %%
tv1=tv.copy()

# %%
tv.reset_index(inplace=True)

# %%
tv
# Out:
#      index    Brand     Resolution  Size   Selling Price  Original Price  \
# 0        0  TOSHIBA   Ultra HD LED     55          37999           54990
# 1        1     TCL   QLED Ultra HD     55          52999          129990
# 2        2  realme          HD LED     32          13999           17999
# 3        3      Mi          HD LED     32          14999           19999
# 4        4  realme          HD LED     32          12999           21999
# ..     ...      ...            ...    ...            ...             ...
# 866    907    SONY     Full HD LED     43          44999           57900
# 867    908    SONY     Full HD LED     40          41499           51900
# 868    909    SONY    Ultra HD LED     65         149990          184990
# 869    910    SONY          HD LED     32          32900           32900
# 870    911    SONY     Full HD LED     43          56900           56900
#
#     Operating System  Rating
# 0              VIDAA     4.3
# 1            Android     4.4
# ...

# %%
tv.drop(['index'],axis=1,inplace=True)

# %%
tv
# Out:
#        Brand     Resolution  Size   Selling Price  Original Price  \
# 0    TOSHIBA   Ultra HD LED     55          37999           54990
# 1       TCL   QLED Ultra HD     55          52999          129990
# 2    realme          HD LED     32          13999           17999
# 3        Mi          HD LED     32          14999           19999
# 4    realme          HD LED     32          12999           21999
# ..       ...            ...    ...            ...             ...
# 866    SONY     Full HD LED     43          44999           57900
# 867    SONY     Full HD LED     40          41499           51900
# 868    SONY    Ultra HD LED     65         149990          184990
# 869    SONY          HD LED     32          32900           32900
# 870    SONY     Full HD LED     43          56900           56900
#
#     Operating System  Rating
# 0              VIDAA     4.3
# 1            Android     4.4
# 2            Android     4.3
# 3            Android     4.4
# ...

# %%
tv.describe()
# Out:
#             Size   Selling Price  Original Price      Rating
# count  871.000000     871.000000      871.000000  871.000000
# mean    46.303100   60347.825488    83513.623421    3.239610
# std     12.205425   66473.367208    85840.729164    1.831858
# min     17.000000    4849.000000     6999.000000    0.000000
# 25%     39.000000   20757.000000    29900.000000    3.150000
# 50%     46.000000   36999.000000    53900.000000    4.200000
# 75%     55.000000   67990.000000    99990.000000    4.400000
# max     85.000000  499990.000000   549990.000000    5.000000

# %%
tv.columns
# Out:
# Index(['Brand', 'Resolution', 'Size ', 'Selling Price', 'Original Price',
#        'Operating System', 'Rating'],
#       dtype='object')

# %%
tv['Brand'].unique()
# Out:
# array(['TOSHIBA', 'TCL ', 'realme ', 'Mi ', 'OnePlus', 'Hisense', 'LG ',
#        'iFFALCON by TCL', 'Coocaa ', 'SAMSUNG', 'Infinix', 'Vu', 'Nokia ',
#        'Thomson', 'SONY ', 'KODAK ', 'MOTOROLA', 'PHILIPS', 'Acer',
#        'Blaupunkt', 'Adsun', 'T-Series', 'Panasonic', 'Micromax',
#        'Sansui ', 'Croma ', 'Candes ', 'Dyanora', 'Haier ', 'Onida',
#        'RGL ', 'Lloyd ', 'LumX ', 'Onix ', 'IMPEX ', 'BPL ',
#        'CloudWalker', 'MarQ by Flipkart', 'Oxygen ', 'Power Guard',
#        'Akai ', 'VG ', 'Compaq ', 'HUIDI ', 'Intex ', 'DETEL ', 'JVC',
#        'G-TEN ', 'Sanyo ', 'Samsung', 'Dektron', 'Sharp ', 'KRISONS',
#        'Weston ', 'AISEN  ', 'MURPHY '], dtype=object)

# %%
tv['Brand'].value_counts()
# Out:
# Brand
# SAMSUNG             140
# LG                  116
# SONY                 61
# TCL                  41
# Panasonic            28
# Micromax             25
# Vu                   23
# Mi                   19
# Lloyd                19
# iFFALCON by TCL      19
# Thomson              18
# Haier                18
# Sansui               17
# PHILIPS              16
# Blaupunkt            15
# KODAK                15
# MOTOROLA             15
# IMPEX                13
# TOSHIBA              13
# Onida                12
# Nokia                11
# Power Guard          11
# Croma                11
# Hisense              10
# OnePlus               9
# T-Series              9
# Coocaa                9
# CloudWalker           9
# Acer                  8
# Sharp                 8
# Onix                  8
# G-TEN                 8
# RGL                   8
# AISEN                 8
# realme                7
# Adsun                 7
# Intex                 7
# JVC                   6
# ...

# %%
plt.figure(figsize=(15, 10))
sns.countplot(data=tv,x='Brand')

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - the most selled brand is samsung
# - behind the samsung Lg is the second most selled brand

# %%
tv11=tv[['Selling Price','Original Price','Rating']].corr()

# %%
tv11
# Out:
#                 Selling Price  Original Price    Rating
# Selling Price        1.000000        0.939391 -0.242372
# Original Price       0.939391        1.000000 -0.222168
# Rating              -0.242372       -0.222168  1.000000

# %%
sns.heatmap(tv11)
# Out:
# <Axes: >

# %%
tv.head(2)
# Out:
#      Brand     Resolution  Size   Selling Price  Original Price  \
# 0  TOSHIBA   Ultra HD LED     55          37999           54990
# 1     TCL   QLED Ultra HD     55          52999          129990
#
#   Operating System  Rating
# 0            VIDAA     4.3
# 1          Android     4.4

# %%
tv2=tv[['Brand','Selling Price','Original Price']].groupby('Brand').sum()

# %%
tv2.sort_values(by='Original Price',ascending=False,inplace=True)

# %%
tv2.reset_index(inplace=True)

# %%
tv2
# Out:
#                Brand  Selling Price  Original Price
# 0            SAMSUNG       14897292        18489265
# 1                LG        11182794        15805865
# 2              SONY         5494356         8039495
# 3               TCL         2144147         4031884
# 4          Panasonic        1547077         2178030
# 5    iFFALCON by TCL        1030454         1899819
# 6                 Vu        1072947         1521484
# 7             Sharp         1197376         1253250
# 8            PHILIPS         573286         1074850
# 9            Hisense         897954         1007900
# 10            Lloyd          652882          999607
# 11            Haier          659092          989581
# 12          Micromax         671739          837938
# 13          MOTOROLA         575985          822389
# 14           Sansui          662805          786328
# 15           Samsung         729780          729780
# 16           TOSHIBA         505087          715906
# ...

# %%
plt.figure(figsize=(10,5))
sns.relplot(data=tv2,x='Selling Price',y='Original Price',style='Brand',s=150)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
res_grp=tv.groupby('Resolution')

# %%
res_grp

# %%
res_grp['Brand'].get_group("HD LED").unique()
# Out:
# array(['realme ', 'Mi ', 'OnePlus', 'LG ', 'Coocaa ', 'TOSHIBA',
#        'Infinix', 'Thomson', 'SONY ', 'SAMSUNG', 'KODAK ', 'MOTOROLA',
#        'Acer', 'Nokia ', 'Adsun', 'TCL ', 'T-Series', 'Micromax',
#        'Croma ', 'Candes ', 'Dyanora', 'Hisense', 'RGL ', 'PHILIPS',
#        'Panasonic', 'Sansui ', 'IMPEX ', 'Onida', 'Blaupunkt', 'Lloyd ',
#        'Power Guard', 'VG ', 'Onix ', 'HUIDI ', 'Intex ', 'LumX ',
#        'Haier ', 'BPL ', 'G-TEN ', 'Vu', 'Dektron', 'iFFALCON by TCL',
#        'CloudWalker', 'Akai ', 'DETEL ', 'KRISONS', 'Compaq ', 'AISEN  ',
#        'JVC', 'MarQ by Flipkart', 'Sharp '], dtype=object)

# %%
tv
# Out:
#        Brand     Resolution  Size   Selling Price  Original Price  \
# 0    TOSHIBA   Ultra HD LED     55          37999           54990
# 1       TCL   QLED Ultra HD     55          52999          129990
# 2    realme          HD LED     32          13999           17999
# 3        Mi          HD LED     32          14999           19999
# 4    realme          HD LED     32          12999           21999
# ..       ...            ...    ...            ...             ...
# 866    SONY     Full HD LED     43          44999           57900
# 867    SONY     Full HD LED     40          41499           51900
# 868    SONY    Ultra HD LED     65         149990          184990
# 869    SONY          HD LED     32          32900           32900
# 870    SONY     Full HD LED     43          56900           56900
#
#     Operating System  Rating
# 0              VIDAA     4.3
# 1            Android     4.4
# 2            Android     4.3
# 3            Android     4.4
# ...

# %%
rating_grp=tv.groupby(['Rating','Resolution'])

# %%
rating_grp['Resolution'].count()
# Out:
# Rating  Resolution
# 0.0     Full HD LED      37
#         HD LED           44
#         HD Plasma         1
#         QLED Ultra HD    25
#         Ultra HD LED     99
#                          ..
# 4.9     Ultra HD LED      1
# 5.0     Full HD LED       5
#         HD LED            2
#         QLED Ultra HD     2
#         Ultra HD LED      9
# Name: Resolution, Length: 73, dtype: int64

# %%
tv['Resolution'].unique()
# Out:
# array(['Ultra HD LED', 'QLED Ultra HD', 'HD LED', 'Full HD LED',
#        'HD Plasma'], dtype=object)

# %%
res_grp['Brand'].get_group('QLED Ultra HD').unique()
# Out:
# array(['TCL ', 'Mi ', 'MOTOROLA', 'Nokia ', 'SAMSUNG', 'iFFALCON by TCL',
#        'Vu', 'Compaq ', 'Power Guard', 'Hisense', 'Akai ', 'OnePlus',
#        'Sansui '], dtype=object)

# %%
tv[tv['Rating']==5]
# Out:
#        Brand     Resolution  Size   Selling Price  Original Price  \
# 164      LG    Ultra HD LED     65         129999          229900
# 211  SAMSUNG  QLED Ultra HD     65         224999          279900
# 224   Haier     Full HD LED     42          28240           43990
# 226    SONY    Ultra HD LED     65         469999          529900
# 243      LG    Ultra HD LED     65         224999          379990
# 325      LG    Ultra HD LED     65         149999          219990
# 328  SAMSUNG  QLED Ultra HD     55         274900          274900
# 342      LG    Ultra HD LED     65         109999          209990
# 357  SAMSUNG   Ultra HD LED     55         154900          154900
# 380   Croma    Ultra HD LED     43          35990           50000
# 532      LG    Ultra HD LED     65         102890          172990
# 537    SONY          HD LED     32          20738           22990
# 666      LG     Full HD LED     47         112000          112000
# ...

# %% [markdown]
# - these are the top or mosted rated tv that are purchased by people

# %%
tv.loc[tv['Rating'].idxmax()]
# Out:
# Brand                        LG
# Resolution          Ultra HD LED
# Size                          65
# Selling Price             129999
# Original Price            229900
# Operating System           WebOS
# Rating                       5.0
# Name: 164, dtype: object

# %%
sns.boxplot(data=tv,x='Original Price')
# Out:
# <Axes: xlabel='Original Price'>

# %%
sns.boxplot(data=tv,x='Selling Price')
# Out:
# <Axes: xlabel='Selling Price'>

# %%
sns.boxplot(data=tv,x='Rating')
# Out:
# <Axes: xlabel='Rating'>

# %%
tv[tv['Rating']==0]
# Out:
#         Brand    Resolution  Size   Selling Price  Original Price  \
# 121  T-Series        HD LED     24           9990           12990
# 151   SAMSUNG  Ultra HD LED     43          41900           49990
# 153       LG   Ultra HD LED     43          41349           57990
# 167    Croma         HD LED     24           7990           15000
# 168       LG   Ultra HD LED     55         137490          299990
# ..        ...           ...    ...            ...             ...
# 846    Sharp    Full HD LED     70         449900          449900
# 847    Sharp    Full HD LED     52         199990          199990
# 848    Sharp    Full HD LED     40         103990          103990
# 856   Sansui   Ultra HD LED     49          59990           59990
# 857   Sansui         HD LED     24          10500           14900
#
#     Operating System  Rating
# 121          Android     0.0
# 151            Tizen     0.0
# 153            WebOS     0.0
# 167          Android     0.0
# ...

# %%
tv['Original Price'].max()
# Out:
# 549990

# %%
tv[tv['Original Price']==549990]
# Out:
#     Brand    Resolution  Size   Selling Price  Original Price  \
# 266   LG   Ultra HD LED     75         385099          549990
#
#     Operating System  Rating
# 266            WebOS     0.0

# %%
tv['Selling Price'].max()
# Out:
# 499990

# %%
tv[tv['Selling Price']==499990]
# Out:
#        Brand     Resolution  Size   Selling Price  Original Price  \
# 497  Hisense  QLED Ultra HD     75         499990          499990
#
#     Operating System  Rating
# 497          Android     0.0

# %%
tv['discount_percentage']=((tv['Original Price']-tv['Selling Price'])/tv['Original Price'])*100

# %%
tv
# Out:
#        Brand     Resolution  Size   Selling Price  Original Price  \
# 0    TOSHIBA   Ultra HD LED     55          37999           54990
# 1       TCL   QLED Ultra HD     55          52999          129990
# 2    realme          HD LED     32          13999           17999
# 3        Mi          HD LED     32          14999           19999
# 4    realme          HD LED     32          12999           21999
# ..       ...            ...    ...            ...             ...
# 866    SONY     Full HD LED     43          44999           57900
# 867    SONY     Full HD LED     40          41499           51900
# 868    SONY    Ultra HD LED     65         149990          184990
# 869    SONY          HD LED     32          32900           32900
# 870    SONY     Full HD LED     43          56900           56900
#
#     Operating System  Rating  discount  discount_percentage
# 0              VIDAA     4.3   1699100            30.898345
# ...

# %%
tv[tv['discount_percentage']>50]
# Out:
#                Brand     Resolution  Size   Selling Price  Original Price  \
# 1               TCL   QLED Ultra HD     55          52999          129990
# 7               TCL    Ultra HD LED     65          57999          119990
# 21   iFFALCON by TCL   Ultra HD LED     55          32999           70990
# 24           Coocaa          HD LED     32          10999           36990
# 48   iFFALCON by TCL    Full HD LED     43          21999           44990
# ..               ...            ...    ...            ...             ...
# 821             RGL     Full HD LED     24           5459           12000
# 841             TCL          HD LED     32           6166           19990
# 842             TCL          HD LED     24           6940           15490
# 843             TCL          HD LED     40           8679           29990
# 865            SONY    Ultra HD LED     49          54999          114900
#
#     Operating System  Rating  discount  discount_percentage
# ...

# %%
tv['discount_percentage'].max()
# Out:
# 71.06035345115038

# %%
tv.loc[tv['discount_percentage'].idxmax()]
# Out:
# Brand                       TCL
# Resolution                HD LED
# Size                          40
# Selling Price               8679
# Original Price             29990
# Operating System          HomeOS
# Rating                       4.0
# discount                 2131100
# discount_percentage    71.060353
# Name: 843, dtype: object

# %% [markdown]
# - the brand TCL given the higest discount which is 71.06

# %%
sort=tv[tv['discount_percentage']<50]

# %%
sort.sort_values(by='discount_percentage',ascending=False,inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12572\2292119099.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sort.sort_values(by='discount_percentage',ascending=False,inplace=True)

# %%
sort
# Out:
#                Brand    Resolution  Size   Selling Price  Original Price  \
# 750  iFFALCON by TCL  Ultra HD LED     65          49999           99990
# 299            SONY   Ultra HD LED     55         164999          329900
# 362             TCL         HD LED     32          15000           29990
# 630              LG         HD LED     24           6765           13490
# 614            LumX         HD LED     32          11990           23900
# ..               ...           ...    ...            ...             ...
# 601            SONY    Full HD LED     52          37900           37900
# 757           Intex    Full HD LED     55          49900           49900
# 610      CloudWalker  Ultra HD LED     55          84500           84500
# 617              LG    Full HD LED     32          31990           31990
# 870            SONY    Full HD LED     43          56900           56900
#
#     Operating System  Rating  discount  discount_percentage
# ...

# %%
tv
# Out:
#        Brand     Resolution  Size   Selling Price  Original Price  \
# 0    TOSHIBA   Ultra HD LED     55          37999           54990
# 1       TCL   QLED Ultra HD     55          52999          129990
# 2    realme          HD LED     32          13999           17999
# 3        Mi          HD LED     32          14999           19999
# 4    realme          HD LED     32          12999           21999
# ..       ...            ...    ...            ...             ...
# 866    SONY     Full HD LED     43          44999           57900
# 867    SONY     Full HD LED     40          41499           51900
# 868    SONY    Ultra HD LED     65         149990          184990
# 869    SONY          HD LED     32          32900           32900
# 870    SONY     Full HD LED     43          56900           56900
#
#     Operating System  Rating  discount  discount_percentage
# 0              VIDAA     4.3   1699100            30.898345
# ...

# %%
tv['Resolution'].value_counts()
# Out:
# Resolution
# Ultra HD LED     390
# HD LED           213
# Full HD LED      205
# QLED Ultra HD     60
# HD Plasma          3
# Name: count, dtype: int64

# %%
sns.countplot(data=tv,x='Resolution')
# Out:
# <Axes: xlabel='Resolution', ylabel='count'>

# %% [markdown]
# - ultra HD LED are the most selled tv
# - HD LED are the second most selled tv

# %%
tvco=tv.copy()

# %%
tv3=tv.sort_values(by='Original Price',ascending=False)

# %%
tv3.head(5)
# Out:
#        Brand     Resolution  Size   Selling Price  Original Price  \
# 266      LG    Ultra HD LED     75         385099          549990
# 226    SONY    Ultra HD LED     65         469999          529900
# 497  Hisense  QLED Ultra HD     75         499990          499990
# 346      LG    Ultra HD LED     65         349999          499990
# 228    SONY    Ultra HD LED     75         259999          499900
#
#     Operating System  Rating  discount  discount_percentage
# 266            WebOS     0.0  16489100            29.980727
# 226          Android     5.0   5990100            11.304208
# 497          Android     0.0         0             0.000000
# 346            WebOS     0.0  14999100            29.998800
# 228          Android     3.7  23990100            47.989798

# %% [markdown]
# - these are the most priced tv
# - LG is the most priced one
# - sony is the second most priced tv

# %%
tv['Operating System'].unique()
# Out:
# array(['VIDAA', 'Android', 'Linux', 'Tizen', 'WebOS', 'HomeOS',
#        'FireTV OS'], dtype=object)

# %%
tv['Operating System'].value_counts(normalize=True)*100
# Out:
# Operating System
# Android      52.353617
# Tizen        16.647532
# Linux        14.006889
# WebOS        11.825488
# HomeOS        3.099885
# VIDAA         1.492537
# FireTV OS     0.574053
# Name: proportion, dtype: float64

# %% [markdown]
# - 52 % people choose android over other operation system

# %%
sns.countplot(data=tv,x='Operating System')
# Out:
# <Axes: xlabel='Operating System', ylabel='count'>

# %%
tv['Size '].unique()
# Out:
# array([55, 32, 43, 65, 40, 50, 70, 24, 42, 58, 49, 39, 48, 75, 85, 31, 28,
#        20, 22, 21, 52, 46, 60, 47, 19, 38, 17], dtype=int64)

# %%
tv['Size '].value_counts()
# Out:
# Size
# 55    167
# 32    161
# 43    157
# 65     99
# 50     71
# 49     57
# 40     39
# 24     34
# 39     16
# 75     14
# 42     10
# 48      6
# 58      5
# 20      5
# 46      5
# 22      5
# 70      4
# 60      4
# 52      2
# 47      2
# 19      2
# 28      1
# 31      1
# 85      1
# 21      1
# 38      1
# 17      1
# Name: count, dtype: int64

# %% [markdown]
# - 55 , 32, and 43 are most considered size by the people

# %%
tv9=tv[['Brand','Selling Price']].groupby('Brand').mean()

# %%
tv9.sort_values(by='Selling Price',ascending=False)
# Out:
#                   Selling Price
# Brand
# Sharp             149672.000000
# Samsung           121630.000000
# SAMSUNG           106409.228571
# LG                 96403.396552
# SONY               90071.409836
# Hisense            89795.400000
# Panasonic          55252.750000
# iFFALCON by TCL    54234.421053
# TCL                52296.268293
# Akai               48183.000000
# OnePlus            47375.777778
# Vu                 46649.869565
# Compaq             45999.000000
# Sanyo              45499.000000
# Weston             43390.000000
# Oxygen             40326.333333
# Sansui             38988.529412
# Nokia              38862.636364
# TOSHIBA            38852.846154
# MOTOROLA           38399.000000
# Haier              36616.222222
# PHILIPS            35830.375000
# AISEN              35462.500000
# BPL                34617.250000
# Lloyd              34362.210526
# Onix               34216.250000
# Acer               33747.875000
# JVC                32496.333333
# ...

# %% [markdown]
# - the average selling price of the brands
# - the sharp have most average selling price

# %%
tv8=tv[['Brand','Selling Price']].groupby('Brand').median()

# %%
tv8.sort_values(by='Selling Price',ascending=False)
# Out:
#                   Selling Price
# Brand
# Sharp                  127990.0
# Samsung                103995.0
# LG                      76737.0
# SAMSUNG                 74490.0
# SONY                    64599.0
# Akai                    51146.0
# OnePlus                 49999.0
# Sanyo                   45499.0
# Panasonic               45129.0
# Weston                  40990.0
# Nokia                   39999.0
# TCL                     39999.0
# Hisense                 39499.0
# iFFALCON by TCL         36999.0
# MOTOROLA                35999.0
# Oxygen                  35990.0
# BPL                     35740.0
# PHILIPS                 35729.0
# Acer                    34994.5
# Compaq                  32999.0
# Onix                    32990.0
# JVC                     32494.5
# Vu                      30999.0
# Haier                   30994.5
# Sansui                  30490.0
# TOSHIBA                 29999.0
# Onida                   29399.5
# IMPEX                   28690.0
# ...

# %% [markdown]
# - these are the mid point of the selling pricing of each brand

# %%
tvr=tv[['Brand','Selling Price','Rating']]

# %%
tvr.sort_values(by='Rating',ascending=False)
# Out:
#          Brand  Selling Price  Rating
# 736     Haier           30999     5.0
# 342        LG          109999     5.0
# 224     Haier           28240     5.0
# 666        LG          112000     5.0
# 211    SAMSUNG         224999     5.0
# ..         ...            ...     ...
# 639  Panasonic          62900     0.0
# 640    KRISONS           6599     0.0
# 121   T-Series           9990     0.0
# 281    SAMSUNG         314900     0.0
# 664    SAMSUNG         218900     0.0
#
# [871 rows x 3 columns]

# %% [markdown]
# - there is no relation between selling price and rating
# - tv with higher selling price doesn't get 5 rating
# - people are  buying the prodcut which is good only
# - the tv with 28k 30k also get 5 rating so this means selling price and rating doesn't mattrer

# %%
tv
# Out:
#        Brand     Resolution  Size   Selling Price  Original Price  \
# 0    TOSHIBA   Ultra HD LED     55          37999           54990
# 1       TCL   QLED Ultra HD     55          52999          129990
# 2    realme          HD LED     32          13999           17999
# 3        Mi          HD LED     32          14999           19999
# 4    realme          HD LED     32          12999           21999
# ..       ...            ...    ...            ...             ...
# 866    SONY     Full HD LED     43          44999           57900
# 867    SONY     Full HD LED     40          41499           51900
# 868    SONY    Ultra HD LED     65         149990          184990
# 869    SONY          HD LED     32          32900           32900
# 870    SONY     Full HD LED     43          56900           56900
#
#     Operating System  Rating  discount  discount_percentage
# 0              VIDAA     4.3   1699100            30.898345
# ...

# %%
ratingavg=tv[['Brand','Rating']].groupby('Brand').mean()

# %%
ratingavg.sort_values(by='Rating',ascending=False)
ratingavg.reset_index(inplace=True)
ratingavg
# Out:
#     index             Brand    Rating
# 0       0           AISEN    0.412500
# 1       1              Acer  3.900000
# 2       2             Adsun  3.800000
# 3       3             Akai   0.000000
# 4       4              BPL   0.925000
# 5       5         Blaupunkt  3.960000
# 6       6           Candes   4.020000
# 7       7       CloudWalker  4.088889
# 8       8           Compaq   4.320000
# 9       9           Coocaa   4.244444
# 10     10            Croma   1.554545
# 11     11            DETEL   4.033333
# 12     12           Dektron  1.075000
# 13     13           Dyanora  1.833333
# 14     14            G-TEN   3.825000
# 15     15            HUIDI   3.416667
# 16     16            Haier   3.155556
# 17     17           Hisense  3.060000
# 18     18            IMPEX   1.915385
# 19     19           Infinix  4.200000
# 20     20            Intex   4.185714
# 21     21               JVC  4.050000
# 22     22            KODAK   4.300000
# 23     23           KRISONS  0.000000
# ...

# %%
sns.catplot(data=ratingavg,x='Brand',y='Rating',kind='bar')

plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
